# %%
import pandas as pd
import matplotlib.dates as mdates
# %matplotlib inline

# %%
merged_all = pd.read_csv('output/merged_all.csv')

# %% [markdown]
# Q: From 2014 to 2019, how many complaints the city received regarding flooding compaints?

# %%
merged_all[merged_all.counts>0]
# Out:
#       Unnamed: 0        date  counts  year  month  day  data_quality  \
# 1              1  2014-01-02       1  2014      1    2           NaN
# 2              2  2014-01-03       1  2014      1    3           NaN
# 5              5  2014-01-06      42  2014      1    6           NaN
# 6              6  2014-01-07       4  2014      1    7           NaN
# 7              7  2014-01-08       4  2014      1    8           NaN
# 8              8  2014-01-09      12  2014      1    9           NaN
# 9              9  2014-01-10     129  2014      1   10           NaN
# 10            10  2014-01-11     278  2014      1   11           NaN
# 11            11  2014-01-12      52  2014      1   12           NaN
# 12            12  2014-01-13      72  2014      1   13           NaN
# 13            13  2014-01-14      44  2014      1   14           NaN
# 14            14  2014-01-15       7  2014      1   15           NaN
# 15            15  2014-01-16       7  2014      1   16           NaN
# ...

# %% [markdown]
# A: There are 1885 days in this time span, among 1576 days, the 311 had at least one call compalainting flooding, counting for 83.6% of all time.

# %% [markdown]
# Q: Which day/year has the largest number of flooding complaints?

# %% [markdown]
# A: Feburary 21, 2014 received the most calls.

# %%
merged_all.sort_values('counts', ascending=False).head()
# Out:
#      Unnamed: 0        date  counts  year  month  day  data_quality  \
# 51           51  2014-02-21     467  2014      2   21           NaN
# 50           50  2014-02-20     452  2014      2   20           NaN
# 49           49  2014-02-19     334  2014      2   19           NaN
# 288         288  2014-10-16     333  2014     10   16           NaN
# 10           10  2014-01-11     278  2014      1   11           NaN
#
#      max_temp_°c max_temp_flag  min_temp_°c  ... total_snow_cm  \
# 51           5.1           NaN          0.7  ...           NaN
# 50           2.6           NaN         -1.0  ...           NaN
# 49           7.8           NaN         -1.4  ...           NaN
# 288         18.6           NaN         12.7  ...           NaN
# 10           7.3           NaN          2.9  ...           NaN
#
#      total_snow_flag total_precip  total_precip_flag snow_on_grnd_cm  \
# 51                 M          8.7                NaN            21.0
# ...

# %% [markdown]
# A: 2014 is the worst year in term of flooding in Toronto.

# %%
merged_all.groupby('year').counts.sum()
# Out:
# year
# 2014    5113
# 2015    2487
# 2016    1263
# 2017    1822
# 2018    2083
# 2019    1246
# Name: counts, dtype: int64

# %% [markdown]
# Q: The correlation between number of calls and percipitations?

# %%
merged_all.head()
# Out:
#    Unnamed: 0        date  counts  year  month  day  data_quality  \
# 0           0  2014-01-01       0  2014      1    1           NaN
# 1           1  2014-01-02       1  2014      1    2           NaN
# 2           2  2014-01-03       1  2014      1    3           NaN
# 3           3  2014-01-04       0  2014      1    4           NaN
# 4           4  2014-01-05       0  2014      1    5           NaN
#
#    max_temp_°c max_temp_flag  min_temp_°c  ... total_snow_cm  total_snow_flag  \
# 0         -8.4           NaN        -14.5  ...           NaN                M
# 1        -14.3           NaN        -19.2  ...           NaN                M
# 2         -7.1           NaN        -22.3  ...           NaN                M
# 3          0.3           NaN         -7.2  ...           NaN                M
# 4          1.4           NaN         -1.7  ...           NaN                M
#
#   total_precip  total_precip_flag snow_on_grnd_cm  snow_on_grnd_flag  \
# ...

# %%
merged2014 = merged_all[merged_all.year==2014]

# %%
merged2015 = merged_all[merged_all.year==2015]

# %%
merged2016 = merged_all[merged_all.year==2016]

# %%
merged2017 = merged_all[merged_all.year==2017]

# %%
merged2018 = merged_all[merged_all.year==2018]

# %%
merged2019 = merged_all[merged_all.year==2019]

# %%
ax = merged2014.plot('date', 'counts')
merged2014.plot('date','total_precip',secondary_y=True, ax=ax, figsize=(15,7))

# %%
ax = merged2015.plot('date', 'counts')
merged2015.plot('date','total_precip',secondary_y=True, ax=ax, figsize=(15,7))

# %%
ax = merged2016.plot('date', 'counts')
merged2016.plot('date','total_precip',secondary_y=True, ax=ax, figsize=(15,7))

# %%
ax = merged2017.plot('date', 'counts')
merged2017.plot('date','total_precip',secondary_y=True, ax=ax, figsize=(15,7))

# %%
ax = merged2018.plot('date', 'counts')
merged2018.plot('date','total_precip',secondary_y=True, ax=ax, figsize=(15,7))

# %%
ax = merged2019.plot('date', 'counts')
merged2019.plot('date','total_precip',secondary_y=True, ax=ax, figsize=(15,7))

# %%
one_more_call = merged_all[merged_all.counts>0]

# %% [markdown]
# Frequency of phone calls each year

# %%
one_more_call.year.value_counts()
# Out:
# 2014    324
# 2015    309
# 2018    302
# 2017    295
# 2016    295
# 2019     51
# Name: year, dtype: int64

# %%
merged2014.to_csv('output/merged2014.csv')

# %%
merged2015.to_csv('output/merged2015.csv')

# %%
merged2016.to_csv('output/merged2016.csv')

# %%
merged2017.to_csv('output/merged2017.csv')

# %%
merged2018.to_csv('output/merged2018.csv')
